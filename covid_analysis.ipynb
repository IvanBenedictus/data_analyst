# %%
import pandas as pd

# %% [markdown]
# ### Import Datasets

# %%
df = pd.read_csv("./other_data/covid19_indonesia.csv")

selected_columns = ["Date", "Location", "New Cases", "New Deaths", "New Recovered", "Longitude", "Latitude"]
covid_df = df[selected_columns]
covid_df.head()
# Out:
#        Date     Location  New Cases  New Deaths  New Recovered   Longitude  \
# 0  3/1/2020  DKI Jakarta          2           0              0  106.836118
# 1  3/2/2020  DKI Jakarta          2           0              0  106.836118
# 2  3/2/2020    Indonesia          2           0              0  113.921327
# 3  3/2/2020         Riau          1           0              0  101.805109
# 4  3/3/2020  DKI Jakarta          2           0              0  106.836118
#
#    Latitude
# 0 -6.204699
# 1 -6.204699
# 2 -0.789275
# 3  0.511648
# 4 -6.204699

# %% [markdown]
# ### Dataset Cleaning

# %%
covid_df.describe(include="all")
# Out:
#             Date     Location     New Cases    New Deaths  New Recovered  \
# count      31822        31822  31822.000000  31822.000000   31822.000000
# unique       930           35           NaN           NaN            NaN
# top     6/9/2021  DKI Jakarta           NaN           NaN            NaN
# freq          35          929           NaN           NaN            NaN
# mean         NaN          NaN    402.311388      9.920652     390.398498
# std          NaN          NaN   2320.629838     64.139080    2199.878802
# min          NaN          NaN      0.000000      0.000000       0.000000
# 25%          NaN          NaN      3.000000      0.000000       2.000000
# 50%          NaN          NaN     27.000000      0.000000      20.000000
# 75%          NaN          NaN    130.000000      3.000000     123.000000
# max          NaN          NaN  64718.000000   2069.000000   61361.000000
#
#            Longitude      Latitude
# count   31822.000000  31822.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean      113.700478     -2.725681
# std         9.862068      3.608065
# min        96.910522     -8.682205
# 25%       106.109004     -6.204699
# 50%       113.417654     -2.461746
# 75%       121.201093      0.212037
# max       138.696030      4.225615

# %%
covid_df[covid_df.isna().any(axis=1)].reset_index(drop=True)

# Replace NaN value with mean value
# value = covid_df["New Cases"].mean()
# covid_df["New Cases"].fillna(value, inplace=True)
# Out:
# Empty DataFrame
# Columns: [Date, Location, New Cases, New Deaths, New Recovered, Longitude, Latitude]
# Index: []

# %%
covid_df[covid_df.duplicated()]

# covid_df = covid_df.drop_duplicates().reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: [Date, Location, New Cases, New Deaths, New Recovered, Longitude, Latitude]
# Index: []

# %%
covid_df.loc[covid_df["New Cases"] == covid_df["New Cases"].max()]
# Out:
#             Date   Location  New Cases  New Deaths  New Recovered   Longitude  \
# 24410  2/16/2022  Indonesia      64718         167          25386  113.921327
#
#        Latitude
# 24410 -0.789275

# %%
covid_df = covid_df.drop(covid_df[covid_df["Location"] == "Indonesia"].index, axis=0).reset_index(drop=True)
covid_df.head()
# Out:
#        Date     Location  New Cases  New Deaths  New Recovered   Longitude  \
# 0  3/1/2020  DKI Jakarta          2           0              0  106.836118
# 1  3/2/2020  DKI Jakarta          2           0              0  106.836118
# 2  3/2/2020         Riau          1           0              0  101.805109
# 3  3/3/2020  DKI Jakarta          2           0              0  106.836118
# 4  3/3/2020   Jawa Barat          1           1              0  107.603708
#
#    Latitude
# 0 -6.204699
# 1 -6.204699
# 2  0.511648
# 3 -6.204699
# 4 -6.920432

# %%
covid_df.describe(include="all")
# Out:
#             Date     Location     New Cases    New Deaths  New Recovered  \
# count      30893        30893  30893.000000  30893.000000   30893.000000
# unique       929           34           NaN           NaN            NaN
# top     6/8/2021  DKI Jakarta           NaN           NaN            NaN
# freq          34          929           NaN           NaN            NaN
# mean         NaN          NaN    207.079565      5.108568     200.840093
# std          NaN          NaN    771.874452     22.344819     813.941207
# min          NaN          NaN      0.000000      0.000000       0.000000
# 25%          NaN          NaN      3.000000      0.000000       2.000000
# 50%          NaN          NaN     24.000000      0.000000      18.000000
# 75%          NaN          NaN    113.000000      3.000000     106.000000
# max          NaN          NaN  16251.000000    545.000000   23872.000000
#
#            Longitude      Latitude
# count   30893.000000  30893.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean      113.693837     -2.783911
# std        10.009183      3.646021
# min        96.910522     -8.682205
# 25%       106.109004     -6.204699
# 50%       112.732941     -2.993595
# 75%       121.201093      0.212037
# max       138.696030      4.225615

# %%
covid_df.loc[covid_df["New Cases"] == covid_df["New Cases"].max()]
# Out:
#             Date    Location  New Cases  New Deaths  New Recovered  \
# 23729  2/17/2022  Jawa Barat      16251          13           3130
#
#         Longitude  Latitude
# 23729  107.603708 -6.920432

# %% [markdown]
# ### Data Exploration

# %%
pd.set_option('display.max_rows', 12)

# %%
min_value = covid_df["Date"].min()
max_value = covid_df["Date"].max()

print(f"The range date for this Analysis is {min_value} - {max_value}")
# Out:
# The range date for this Analysis is 1/1/2021 - 9/9/2022

# %%
covid_df.groupby(by="Location").Date.count()
# Out:
# Location
# Aceh                 904
# Bali                 919
# Banten               924
# Bengkulu             899
# DKI Jakarta          929
#                     ...
# Sulawesi Tenggara    920
# Sulawesi Utara       904
# Sumatera Barat       904
# Sumatera Selatan     907
# Sumatera Utara       913
# Name: Date, Length: 34, dtype: int64

# %%
covid_df.sort_values(by="New Cases", ascending=False).head(5).reset_index(drop=True)
# Out:
#         Date     Location  New Cases  New Deaths  New Recovered   Longitude  \
# 0  2/17/2022   Jawa Barat      16251          13           3130  107.603708
# 1   2/6/2022  DKI Jakarta      15825          28           8309  106.836118
# 2  2/16/2022   Jawa Barat      15196          15           5413  107.603708
# 3  7/12/2021  DKI Jakarta      14622         134          20477  106.836118
# 4   2/9/2022  DKI Jakarta      14353          17           8893  106.836118
#
#    Latitude
# 0 -6.920432
# 1 -6.204699
# 2 -6.920432
# 3 -6.204699
# 4 -6.204699

# %%
covid_df["Emergency Level"] = "Green"
covid_df.loc[(covid_df["New Cases"] >= 3000) & (covid_df["New Cases"] < 6000), "Emergency Level"] = "Yellow"
covid_df.loc[(covid_df["New Cases"] >= 6000) & (covid_df["New Cases"] < 12000), "Emergency Level"] = "Orange"
covid_df.loc[covid_df["New Cases"] >= 12000, "Emergency Level"] = "Red"

covid_df.groupby(by="Emergency Level").Date.count().loc[["Green", "Yellow", "Orange", "Red"]]
# Out:
# Emergency Level
# Green     30528
# Yellow      238
# Orange      102
# Red          25
# Name: Date, dtype: int64

# %%
covid_df["Date"] = pd.to_datetime(covid_df["Date"])

# Create new columns for year and month
covid_df["Year"] = covid_df["Date"].dt.year
covid_df["Month"] = covid_df["Date"].dt.month

# Group month by Quarter
covid_df.loc[(covid_df["Month"] >= 1) & (covid_df["Month"] < 4), "Quarter"] = "Q1"
covid_df.loc[(covid_df["Month"] >= 4) & (covid_df["Month"] < 7), "Quarter"] = "Q2"
covid_df.loc[(covid_df["Month"] >= 7) & (covid_df["Month"] < 10), "Quarter"] = "Q3"
covid_df.loc[(covid_df["Month"] >= 10) & (covid_df["Month"] < 13), "Quarter"] = "Q4"

covid_df.groupby(by=["Year", "Quarter"]).agg({
    "New Cases": "sum",
    "New Deaths": "sum",
    "New Recovered": "sum"
})
# Out:
#               New Cases  New Deaths  New Recovered
# Year Quarter
# 2020 Q1            1020         186            191
#      Q2           56586        3136          28043
#      Q3          233326        8008         186237
#      Q4          459916       11663         409289
# 2021 Q1          762803       18282         729770
#      Q2          669353       17861         530259
#      Q3         2031992       82916        2152458
#      Q4           47653        2084          77825
# 2022 Q1         1750101       11018        1635253
#      Q2           75649        1623         164878
#      Q3          308910        1042         290350
